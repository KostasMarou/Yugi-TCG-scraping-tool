# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import re
from collections import defaultdict

# Load the data from the Excel file  FIX PATH TO YOUR FILE (the actual file is available on my Git-hub)
file_path = r"C:\Users\.........\fullYugiohListScrape.xlsx"
df = pd.read_excel(file_path)
card_names = df.iloc[:, 0].tolist()

# Set up Edge WebDriver
driver = webdriver.Edge()
driver.get("https://www.cardmarket.com/en/YuGiOh")
time.sleep(3)

# Dictionary to store the lowest-price sellers for each card
card_data = {}

# Function to clean card names by removing special characters
def clean_name(name):
    return re.sub(r"[^a-zA-Z0-9\s]", "", name)

# Loop through the first 10 cards in the card_names list
for card_name in card_names[:15]:
    cleaned_name = clean_name(card_name)
    print(f"Processing card: {card_name} (cleaned name: {cleaned_name})")
    
    try:
        # Find and use the search bar
        search_bar = driver.find_element(By.NAME, "searchString")
        search_bar.clear()
        search_bar.send_keys(card_name)
        search_bar.send_keys(Keys.RETURN)
        time.sleep(3)

        # Retry finding the link a couple of times if not successful on the first try
        for _ in range(3):
            try:
                card_link = driver.find_element(By.XPATH, f"//a[contains(translate(text(), 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), '{cleaned_name.lower()}')]")
                card_link.click()
                print(f"Clicked on the link for card: {card_name}")
                time.sleep(3)
                break
            except:
                print(f"Retry finding link for card: {card_name}")
                time.sleep(2)
        else:
            print(f"Could not find a link for card: {card_name}")
            continue

        # Find and click "Show Offers" if available
        try:
            show_offers_link = driver.find_element(By.LINK_TEXT, "Show Offers")
            show_offers_link.click()
            print("Clicked on 'Show Offers' link.")
            time.sleep(3)
        except:
            print("Could not find the 'Show Offers' link.")
            continue

        # Initialize list to store lowest-price sellers for this card
        sellers_prices = []
        lowest_price = None  # Variable to track the lowest price for this card
        
        # Find all rows with the 'article-row' class
        rows = driver.find_elements(By.CLASS_NAME, "article-row")
        for row in rows:
            try:
                seller = row.find_element(By.CSS_SELECTOR, ".col-sellerProductInfo .seller-name span a").text
                price_text = row.find_element(By.CSS_SELECTOR, ".price-container .fw-bold").text
                price = float(price_text.replace(",", ".").replace(" €", ""))  # Convert price to float
                
                # Check if this price is the lowest for the current card
                if lowest_price is None or price < lowest_price:
                    # Found a new lowest price, reset the list
                    lowest_price = price
                    sellers_prices = [(seller, price_text)]
                elif price == lowest_price:
                    # Same as current lowest price, add this seller
                    sellers_prices.append((seller, price_text))
            except Exception as e:
                print(f"Error extracting data from row: {e}")

        # Save data for the current card
        card_data[card_name] = sellers_prices
        print(f"Data collected for {card_name}: {sellers_prices}")

        # Go back to the homepage to search for the next card
        driver.get("https://www.cardmarket.com/en/YuGiOh")
        time.sleep(3)

    except Exception as e:
        print(f"An error occurred while processing card '{card_name}': {e}")



# Step 2: Identify the seller with the most low-priced cards
seller_count = defaultdict(int)  # Dictionary to count the occurrences of each seller

# Count each seller's appearance across all cards
for card, sellers in card_data.items():
    for seller, price in sellers:
        seller_count[seller] += 1

# Find the seller with the most low-priced cards
best_seller = max(seller_count, key=seller_count.get)
print(f"Seller with the most low-priced cards: {best_seller}")

# Step 3: Create a list of all cards and prices for the best seller
best_seller_cards = [(card, price) for card, sellers in card_data.items() for seller, price in sellers if seller == best_seller]
print(f"Cards sold by {best_seller} at the lowest price: {best_seller_cards}")


#NOW SAVING DATA IN A TABLE [FIX PATH]
best_seller_df = pd.DataFrame(best_seller_cards, columns=["Card Name", "Price"])

# Define the file path for the output Excel file
output_file_path = r"C:\Users\...........\FilesName.xlsx"

# Save the DataFrame to an Excel file
best_seller_df.to_excel(output_file_path, index=False)

print(f"Excel file has been created at: {output_file_path}")
# Out:
# Processing card: Recycling Batteries (cleaned name: Recycling Batteries)
# Clicked on the link for card: Recycling Batteries
# Clicked on 'Show Offers' link.
# Data collected for Recycling Batteries: [('Cardaccess', '0,02 €'), ('Ultimate-Geier', '0,02 €'), ('Ultimate-Geier', '0,02 €'), ('Attardauctions', '0,02 €'), ('namenick', '0,02 €'), ('Schlee1312', '0,02 €'), ('tobirama83', '0,02 €'), ('Heidi9-co', '0,02 €'), ('zarcenas', '0,02 €'), ('Yubel44', '0,02 €'), ('sacriemof', '0,02 €'), ('sacriemof', '0,02 €'), ('VanNisthath', '0,02 €'), ('VanNisthath', '0,02 €'), ('ilcici', '0,02 €'), ('Frostin', '0,02 €'), ('Troufiniou', '0,02 €'), ('mattefratus95', '0,02 €'), ('mattefratus95', '0,02 €'), ('roberta1964', '0,02 €'), ('TopCut', '0,02 €'), ('BOXEUR-THAI63', '0,02 €'), ('Espell', '0,02 €'), ('mayhem28', '0,02 €'), ('mayhem28', '0,02 €'), ('dudelbert', '0,02 €'), ('Bromania', '0,02 €'), ('Seiya1980', '0,02 €'), ('pophip', '0,02 €'), ('Donatocard98', '0,02 €'), ('CARTAGOGO', '0,02 €'), ('keininsder', '0,02 €'), ('Jooserra', '0,02 €'), ('Jooserra', '0,02 €'), ('KURIBOOH82', '0,02 €'), ('Tryce', '0,02 €'), ('Kevinlaflair', '0,02 €'), ('Kevinlaflair', '0,02 €'), ('Lunaria101', '0,02 €'), ('pokenightmare', '0,02 €'), ('Folof14', '0,02 €'), ('Alexelix', '0,02 €'), ('kcarhartt', '0,02 €'), ('kcarhartt', '0,02 €'), ('mtg-collector1', '0,02 €'), ('riri025', '0,02 €'), ('MacciJr', '0,02 €'), ('RED95', '0,02 €'), ('rollergrome', '0,02 €'), ('tenten1806', '0,02 €')]
# Processing card: Raijin the Breakbolt Star (cleaned name: Raijin the Breakbolt Star)
# Clicked on the link for card: Raijin the Breakbolt Star
# Clicked on 'Show Offers' link.
# Processing card: RESCUE! (cleaned name: RESCUE)
# Clicked on the link for card: RESCUE!
# Could not find the 'Show Offers' link.
# Processing card: Imperial Custom (cleaned name: Imperial Custom)
# Clicked on the link for card: Imperial Custom
# Clicked on 'Show Offers' link.
# Data collected for Imperial Custom: [('Hobby-Games', '0,02 €'), ('Cardaccess', '0,02 €'), ('c4gamers', '0,02 €'), ('YuGiBroShop', '0,02 €'), ('DRACO-TEAM', '0,02 €'), ('Monoblack69', '0,02 €'), ('Monoblack69', '0,02 €'), ('MythicVault', '0,02 €'), ('busterblader', '0,02 €'), ('anjuri007', '0,02 €'), ('ggitsyours', '0,02 €'), ('ggitsyours', '0,02 €'), ('ggitsyours', '0,02 €'), ('ggitsyours', '0,02 €'), ('SG1Sam', '0,02 €'), ('Attardauctions', '0,02 €'), ('Attardauctions', '0,02 €'), ('CardCastleGR', '0,02 €'), ('Schlee1312', '0,02 €'), ('tisidar', '0,02 €'), ('bladde17', '0,02 €'), ('PresticardsFrance', '0,02 €'), ('Sora-Ai', '0,02 €'), ('L-espoir-Du-Jeu', '0,02 €'), ('L-espoir-Du-Jeu', '0,02 €'), ('DREAM-CARDS', '0,02 €'), ('Yugi6222', '0,02 €'), ('Albobest', '0,02 €'), ('Albobest', '0,02 €'), ('Tony2510', '0,02 €'), ('spielewelt-jung', '0,02 €'), ('Toy-Tiger', '0,02 €'), ('sacriemof', '0,02 €'), ('sacriemof', '0,02 €'), ('sacriemof', '0,02 €'), ('ilcici', '0,02 €'), ('ilcici', '0,02 €'), ('Triny51100', '0,02 €'), ('Kabi18', '0,02 €'), ('Kabi18', '0,02 €'), ('Kabi18', '0,02 €'), ('Kabi18', '0,02 €'), ('Troufiniou', '0,02 €'), ('illuminight', '0,02 €'), ('Poppy92', '0,02 €'), ('Poppy92', '0,02 €'), ('Maxwell99', '0,02 €'), ('Ysano', '0,02 €'), ('Ysano', '0,02 €'), ('PassionCards', '0,02 €')]
# Processing card: Taotie, Shadow of the Yang Zing (cleaned name: Taotie Shadow of the Yang Zing)
# Retry finding link for card: Taotie, Shadow of the Yang Zing
# Retry finding link for card: Taotie, Shadow of the Yang Zing
# Retry finding link for card: Taotie, Shadow of the Yang Zing
# Could not find a link for card: Taotie, Shadow of the Yang Zing
# Processing card: Frost Blast of the Monarchs (cleaned name: Frost Blast of the Monarchs)
# Clicked on the link for card: Frost Blast of the Monarchs
# Clicked on 'Show Offers' link.
# Data collected for Frost Blast of the Monarchs: [('Yugitradematttt', '0,02 €')]
# Processing card: T.G. Star Guardian (cleaned name: TG Star Guardian)
# Retry finding link for card: T.G. Star Guardian
# Retry finding link for card: T.G. Star Guardian
# Retry finding link for card: T.G. Star Guardian
# Could not find a link for card: T.G. Star Guardian
# Processing card: Mudora the Sword Oracle (cleaned name: Mudora the Sword Oracle)
# Clicked on the link for card: Mudora the Sword Oracle
# Clicked on 'Show Offers' link.
# Data collected for Mudora the Sword Oracle: [('FantasySphere', '0,10 €'), ('Aatu922', '0,10 €'), ('Italyan', '0,10 €'), ('ELIO37', '0,10 €'), ('Maruzz', '0,10 €'), ('burak22', '0,10 €'), ('DokSev', '0,10 €'), ('Tulio9822', '0,10 €')]
# Processing card: Adamancipator Friends (cleaned name: Adamancipator Friends)
# Clicked on the link for card: Adamancipator Friends
# Clicked on 'Show Offers' link.
# Data collected for Adamancipator Friends: [('BetaCards', '0,02 €'), ('BetaCards', '0,02 €'), ('TopNard', '0,02 €'), ('Hybris', '0,02 €'), ('L-espoir-Du-Jeu', '0,02 €'), ('Whitebeard999', '0,02 €'), ('Seronia92', '0,02 €'), ('Empire-of-Cards', '0,02 €'), ('Kabi18', '0,02 €'), ('Maxwell99', '0,02 €'), ('Seiyaryu', '0,02 €'), ('Kaiba-Corp', '0,02 €'), ('KURIBOOH82', '0,02 €'), ('Tryce', '0,02 €'), ('strk27', '0,02 €'), ('mathvill12', '0,02 €'), ('mathvill12', '0,02 €'), ('Sanaito', '0,02 €'), ('BerettaZero', '0,02 €'), ('Volgera', '0,02 €'), ('Madibba', '0,02 €'), ('SGM-SenGoldMania', '0,02 €'), ('SGM-SenGoldMania', '0,02 €'), ('SGM-SenGoldMania', '0,02 €'), ('darkZerua', '0,02 €'), ('darkZerua', '0,02 €'), ('Keijou', '0,02 €'), ('DJQCify', '0,02 €'), ('Kleingeldmann', '0,02 €'), ('Yugushuri', '0,02 €'), ('Creysey', '0,02 €'), ('Jules-WNA', '0,02 €'), ('Onepunchman67', '0,02 €'), ('Possi90', '0,02 €'), ('Narjes', '0,02 €'), ('castelcards', '0,02 €'), ('louislapitrerie', '0,02 €'), ('Zirkhov7', '0,02 €'), ('Konsumkreis', '0,02 €'), ('c4lemons', '0,02 €'), ('PippoBaida', '0,02 €'), ('vixorr', '0,02 €'), ('Fabiob94', '0,02 €'), ('Schrodan89', '0,02 €'), ('Ethenight', '0,02 €'), ('Kuem-Cards', '0,02 €'), ('Retchut', '0,02 €'), ('p4ul39', '0,02 €'), ('Akoji', '0,02 €')]
# Processing card: Naturia Exterio (cleaned name: Naturia Exterio)
# Clicked on the link for card: Naturia Exterio
# Clicked on 'Show Offers' link.
# Data collected for Naturia Exterio: [('Sammy49300', '0,10 €'), ('Seanyface', '0,10 €')]
# Processing card: Predaplant Drosophyllum Hydra (cleaned name: Predaplant Drosophyllum Hydra)
# Clicked on the link for card: Predaplant Drosophyllum Hydra
# Clicked on 'Show Offers' link.
# Processing card: Chow Chow Chan (cleaned name: Chow Chow Chan)
# Clicked on the link for card: Chow Chow Chan
# Clicked on 'Show Offers' link.
# Data collected for Chow Chow Chan: [('Cardaccess', '0,02 €'), ('Cardaccess', '0,02 €'), ('Cardaccess', '0,02 €'), ('Animehousegr', '0,02 €'), ('BlackFlameGreece', '0,02 €'), ('lolloveratti', '0,02 €'), ('Attardauctions', '0,02 €'), ('EXODIAA82', '0,02 €'), ('EXODIAA82', '0,02 €'), ('EXODIAA82', '0,02 €'), ('namenick', '0,02 €'), ('AltdorGames', '0,02 €'), ('AltdorGames', '0,02 €'), ('ItsTimeToDuel-Anto', '0,02 €'), ('TopNard', '0,02 €'), ('TopNard', '0,02 €'), ('berjackie', '0,02 €'), ('Hybris', '0,02 €'), ('Hybris', '0,02 €'), ('Hybris', '0,02 €'), ('Yugi6222', '0,02 €'), ('Albobest', '0,02 €'), ('Albobest', '0,02 €'), ('Albobest', '0,02 €'), ('Mogliettina74', '0,02 €'), ('meldaur', '0,02 €'), ('PIXHERO-fr', '0,02 €'), ('PIXHERO-fr', '0,02 €'), ('ilcici', '0,02 €'), ('ilcici', '0,02 €'), ('GOARLINE', '0,02 €'), ('Kabi18', '0,02 €'), ('Kabi18', '0,02 €'), ('mattefratus95', '0,02 €'), ('roberta1964', '0,02 €'), ('roberta1964', '0,02 €'), ('zigomio', '0,02 €'), ('TopCut', '0,02 €'), ('DjBilly', '0,02 €'), ('illuminight', '0,02 €'), ('Poppy92', '0,02 €'), ('Poppy92', '0,02 €'), ('BOXEUR-THAI63', '0,02 €'), ('BOXEUR-THAI63', '0,02 €'), ('DemonOni', '0,02 €'), ('CDouble22', '0,02 €'), ('ilregnodelleombre', '0,02 €'), ('megalan21', '0,02 €'), ('Espell', '0,02 €'), ('smatts', '0,02 €')]
# Processing card: Skull Flame (cleaned name: Skull Flame)
# Clicked on the link for card: Skull Flame
# Clicked on 'Show Offers' link.
# Data collected for Skull Flame: [('ggitsyours', '0,10 €')]
# Seller with the most low-priced cards: BetaCards
# Cards sold by BetaCards at the lowest price: [('Adamancipator Friends', '0,02 €'), ('Adamancipator Friends', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €'), ('Mokey Mokey Adrift', '0,02 €')]
# Excel file has been created at: C:\Users\marou\OneDrive\Υπολογιστής\yugi project\saveResults.xlsx
